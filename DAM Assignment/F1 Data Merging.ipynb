# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set()

# %%
constructor_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/constructors.csv")
print(constructor_df.head(10))
# Out:
#    constructorId constructorRef         name nationality  \
# 0              1        mclaren      McLaren     British
# 1              2     bmw_sauber   BMW Sauber      German
# 2              3       williams     Williams     British
# 3              4        renault      Renault      French
# 4              5     toro_rosso   Toro Rosso     Italian
# 5              6        ferrari      Ferrari     Italian
# 6              7         toyota       Toyota    Japanese
# 7              8    super_aguri  Super Aguri    Japanese
# 8              9       red_bull     Red Bull    Austrian
# 9             10    force_india  Force India      Indian
#
#                                                  url  Unnamed: 5
# 0               http://en.wikipedia.org/wiki/McLaren         NaN
# 1            http://en.wikipedia.org/wiki/BMW_Sauber         NaN
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...         NaN
# 3            http://en.wikipedia.org/wiki/Renault_F1         NaN
# ...

# %%
constructor_results_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/constructorResults.csv")
print(constructor_results_df.head(10))
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0    NaN
# 1                     2      18              2     8.0    NaN
# 2                     3      18              3     9.0    NaN
# 3                     4      18              4     5.0    NaN
# 4                     5      18              5     2.0    NaN
# 5                     6      18              6     1.0    NaN
# 6                     7      18              7     0.0    NaN
# 7                     8      18              8     0.0    NaN
# 8                     9      18              9     0.0    NaN
# 9                    10      18             10     0.0    NaN

# %%
constructor_combined = pd.merge(constructor_df, constructor_results_df, on='constructorId')
print(constructor_combined.head(10))
# Out:
#    constructorId constructorRef     name nationality  \
# 0              1        mclaren  McLaren     British
# 1              1        mclaren  McLaren     British
# 2              1        mclaren  McLaren     British
# 3              1        mclaren  McLaren     British
# 4              1        mclaren  McLaren     British
# 5              1        mclaren  McLaren     British
# 6              1        mclaren  McLaren     British
# 7              1        mclaren  McLaren     British
# 8              1        mclaren  McLaren     British
# 9              1        mclaren  McLaren     British
#
#                                     url  Unnamed: 5  constructorResultsId  \
# 0  http://en.wikipedia.org/wiki/McLaren         NaN                     1
# 1  http://en.wikipedia.org/wiki/McLaren         NaN                    14
# 2  http://en.wikipedia.org/wiki/McLaren         NaN                    25
# 3  http://en.wikipedia.org/wiki/McLaren         NaN                    35
# ...

# %%
constructor_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11142 entries, 0 to 11141
# Data columns (total 10 columns):
# constructorId           11142 non-null int64
# constructorRef          11142 non-null object
# name                    11142 non-null object
# nationality             11142 non-null object
# url                     11142 non-null object
# Unnamed: 5              0 non-null float64
# constructorResultsId    11142 non-null int64
# raceId                  11142 non-null int64
# points                  11142 non-null float64
# status                  17 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 957.5+ KB

# %%
races_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/races.csv")
print(races_df.head(10))
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
# 5       6  2009      6          6      Monaco Grand Prix  2009-05-24
# 6       7  2009      7          5     Turkish Grand Prix  2009-06-07
# 7       8  2009      8          9     British Grand Prix  2009-06-21
# 8       9  2009      9         20      German Grand Prix  2009-07-12
# 9      10  2009     10         11   Hungarian Grand Prix  2009-07-26
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# ...

# %%
constructor_combined = pd.merge(constructor_combined, races_df, on='raceId')
print(constructor_combined.head(10))
# Out:
#    constructorId constructorRef       name_x nationality  \
# 0              1        mclaren      McLaren     British
# 1              2     bmw_sauber   BMW Sauber      German
# 2              3       williams     Williams     British
# 3              4        renault      Renault      French
# 4              5     toro_rosso   Toro Rosso     Italian
# 5              6        ferrari      Ferrari     Italian
# 6              7         toyota       Toyota    Japanese
# 7              8    super_aguri  Super Aguri    Japanese
# 8              9       red_bull     Red Bull    Austrian
# 9             10    force_india  Force India      Indian
#
#                                                url_x  Unnamed: 5  \
# 0               http://en.wikipedia.org/wiki/McLaren         NaN
# 1            http://en.wikipedia.org/wiki/BMW_Sauber         NaN
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...         NaN
# 3            http://en.wikipedia.org/wiki/Renault_F1         NaN
# ...

# %%
constructor_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11142 entries, 0 to 11141
# Data columns (total 17 columns):
# constructorId           11142 non-null int64
# constructorRef          11142 non-null object
# name_x                  11142 non-null object
# nationality             11142 non-null object
# url_x                   11142 non-null object
# Unnamed: 5              0 non-null float64
# constructorResultsId    11142 non-null int64
# raceId                  11142 non-null int64
# points                  11142 non-null float64
# status                  17 non-null object
# year                    11142 non-null int64
# round                   11142 non-null int64
# circuitId               11142 non-null int64
# name_y                  11142 non-null object
# date                    11142 non-null object
# time                    2661 non-null object
# url_y                   11142 non-null object
# dtypes: float64(2), int64(6), object(9)
# memory usage: 1.5+ MB

# %%
constructor_combined.drop(['Unnamed: 5','time','status','constructorResultsId'],axis='columns', inplace=True)
print(constructor_combined.head(10))
# Out:
#    constructorId constructorRef       name_x nationality  \
# 0              1        mclaren      McLaren     British
# 1              2     bmw_sauber   BMW Sauber      German
# 2              3       williams     Williams     British
# 3              4        renault      Renault      French
# 4              5     toro_rosso   Toro Rosso     Italian
# 5              6        ferrari      Ferrari     Italian
# 6              7         toyota       Toyota    Japanese
# 7              8    super_aguri  Super Aguri    Japanese
# 8              9       red_bull     Red Bull    Austrian
# 9             10    force_india  Force India      Indian
#
#                                                url_x  raceId  points  year  \
# 0               http://en.wikipedia.org/wiki/McLaren      18    14.0  2008
# 1            http://en.wikipedia.org/wiki/BMW_Sauber      18     8.0  2008
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...      18     9.0  2008
# ...

# %%
constructor_combined.rename(columns = {'url_x': 'constructor_url', 'url_y': 'race_url','name_x': 'Constructor_name', 'name_y':'grand_prix_name'}, inplace = True)
print(constructor_combined.head(10))
# Out:
#    constructorId constructorRef Constructor_name nationality  \
# 0              1        mclaren          McLaren     British
# 1              2     bmw_sauber       BMW Sauber      German
# 2              3       williams         Williams     British
# 3              4        renault          Renault      French
# 4              5     toro_rosso       Toro Rosso     Italian
# 5              6        ferrari          Ferrari     Italian
# 6              7         toyota           Toyota    Japanese
# 7              8    super_aguri      Super Aguri    Japanese
# 8              9       red_bull         Red Bull    Austrian
# 9             10    force_india      Force India      Indian
#
#                                      constructor_url  raceId  points  year  \
# 0               http://en.wikipedia.org/wiki/McLaren      18    14.0  2008
# 1            http://en.wikipedia.org/wiki/BMW_Sauber      18     8.0  2008
# ...

# %%
constructor_combined.sort_values(by=['year'], inplace=True)

# %%
constructor_combined.to_csv('F1 data/constructors_combined_data.csv')

# %%
driver_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/drivers.csv")
print(driver_df.head(10))
# Out:
#    driverId   driverRef  number code          H     surname         dob  \
# 0         1    hamilton    44.0  HAM      Lewis    Hamilton    7/1/1985
# 1         2    heidfeld     NaN  HEI       Nick    Heidfeld   10/5/1977
# 2         3     rosberg     6.0  ROS       Nico     Rosberg   27/6/1985
# 3         4      alonso    14.0  ALO   Fernando      Alonso   29/7/1981
# 4         5  kovalainen     NaN  KOV     Heikki  Kovalainen  19/10/1981
# 5         6    nakajima     NaN  NAK     Kazuki    Nakajima   11/1/1985
# 6         7    bourdais     NaN  BOU  Sebastien    Bourdais   28/2/1979
# 7         8   raikkonen     7.0  RAI       Kimi   Raikkonen  17/10/1979
# 8         9      kubica     NaN  KUB     Robert      Kubica   7/12/1984
# 9        10       glock     NaN  GLO       Timo       Glock   18/3/1982
#
#   nationality                                                url
# 0     British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# ...

# %%
driver_results_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/results.csv")
print(driver_results_df.head(10))
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
# 5         6      18         6              3     8.0    13       6.0
# 6         7      18         7              5    14.0    17       7.0
# 7         8      18         8              6     1.0    15       8.0
# 8         9      18         9              2     4.0     2       NaN
# 9        10      18        10              7    12.0    18       NaN
#
#   positionText  positionOrder  points  laps     time  milliseconds  \
# 0            1              1    10.0    58  34:50.6     5690616.0
# 1            2              2     8.0    58    5.478     5696094.0
# ...

# %%
driver_combined = pd.merge(driver_df, driver_results_df, on='driverId')
print(driver_combined.head(10))
# Out:
#    driverId driverRef  number_x code      H   surname       dob nationality  \
# 0         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 1         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 2         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 3         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 4         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 5         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 6         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 7         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 8         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 9         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
#
#                                            url  resultId  ...  positionOrder  \
# ...

# %%
status_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/status.csv")
print(status_df.head(10))
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine
# 5         6       Gearbox
# 6         7  Transmission
# 7         8        Clutch
# 8         9    Hydraulics
# 9        10    Electrical

# %%
driver_combined = pd.merge(driver_combined, status_df, on='statusId')
print(driver_combined.head(10))
# Out:
#    driverId driverRef  number_x code      H   surname       dob nationality  \
# 0         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 1         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 2         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 3         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 4         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 5         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 6         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 7         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 8         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
# 9         1  hamilton      44.0  HAM  Lewis  Hamilton  7/1/1985     British
#
#                                            url  resultId  ...  points  laps  \
# ...

# %%
races_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/races.csv")
print(races_df.head(10))
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
# 5       6  2009      6          6      Monaco Grand Prix  2009-05-24
# 6       7  2009      7          5     Turkish Grand Prix  2009-06-07
# 7       8  2009      8          9     British Grand Prix  2009-06-21
# 8       9  2009      9         20      German Grand Prix  2009-07-12
# 9      10  2009     10         11   Hungarian Grand Prix  2009-07-26
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# ...

# %%
driver_combined = pd.merge(driver_combined, races_df, on='raceId')
print(driver_combined.head(10))
# Out:
#    driverId   driverRef  number_x code         H     surname         dob  \
# 0         1    hamilton      44.0  HAM     Lewis    Hamilton    7/1/1985
# 1         2    heidfeld       NaN  HEI      Nick    Heidfeld   10/5/1977
# 2         3     rosberg       6.0  ROS      Nico     Rosberg   27/6/1985
# 3         4      alonso      14.0  ALO  Fernando      Alonso   29/7/1981
# 4         5  kovalainen       NaN  KOV    Heikki  Kovalainen  19/10/1981
# 5         6    nakajima       NaN  NAK    Kazuki    Nakajima   11/1/1985
# 6         9      kubica       NaN  KUB    Robert      Kubica   7/12/1984
# 7        14   coulthard       NaN  COU     David   Coulthard   27/3/1971
# 8        17      webber       NaN  WEB      Mark      Webber   27/8/1976
# 9        18      button      22.0  BUT    Jenson      Button   19/1/1980
#
#   nationality                                           url_x  resultId  ...  \
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton         1  ...
# ...

# %%
driver_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23777 entries, 0 to 23776
# Data columns (total 34 columns):
# driverId           23777 non-null int64
# driverRef          23777 non-null object
# number_x           3447 non-null float64
# code               7199 non-null object
# H                  23777 non-null object
# surname            23777 non-null object
# dob                23776 non-null object
# nationality        23777 non-null object
# url_x              23776 non-null object
# resultId           23777 non-null int64
# raceId             23777 non-null int64
# constructorId      23777 non-null int64
# number_y           23771 non-null float64
# grid               23777 non-null int64
# position           13227 non-null float64
# positionText       23777 non-null object
# positionOrder      23777 non-null int64
# points             23777 non-null float64
# laps               23777 non-null int64
# time_x             6004 non-null object
# ...

# %%
driver_combined.drop(['number_x','code','time_y','statusId'],axis='columns', inplace=True)
print(driver_combined.head(20))
# Out:
#     driverId    driverRef          H      surname         dob nationality  \
# 0          1     hamilton      Lewis     Hamilton    7/1/1985     British
# 1          2     heidfeld       Nick     Heidfeld   10/5/1977      German
# 2          3      rosberg       Nico      Rosberg   27/6/1985      German
# 3          4       alonso   Fernando       Alonso   29/7/1981     Spanish
# 4          5   kovalainen     Heikki   Kovalainen  19/10/1981     Finnish
# 5          6     nakajima     Kazuki     Nakajima   11/1/1985    Japanese
# 6          9       kubica     Robert       Kubica   7/12/1984      Polish
# 7         14    coulthard      David    Coulthard   27/3/1971     British
# 8         17       webber       Mark       Webber   27/8/1976  Australian
# 9         18       button     Jenson       Button   19/1/1980     British
# 10        19     davidson    Anthony     Davidson   18/4/1979     British
# 11        20       vettel  Sebastian       Vettel    3/7/1987      German
# ...

# %%
driver_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23777 entries, 0 to 23776
# Data columns (total 30 columns):
# driverId           23777 non-null int64
# driverRef          23777 non-null object
# H                  23777 non-null object
# surname            23777 non-null object
# dob                23776 non-null object
# nationality        23777 non-null object
# url_x              23776 non-null object
# resultId           23777 non-null int64
# raceId             23777 non-null int64
# constructorId      23777 non-null int64
# number_y           23771 non-null float64
# grid               23777 non-null int64
# position           13227 non-null float64
# positionText       23777 non-null object
# positionOrder      23777 non-null int64
# points             23777 non-null float64
# laps               23777 non-null int64
# time_x             6004 non-null object
# milliseconds       6003 non-null float64
# fastestLap         5383 non-null float64
# ...

# %%
driver_combined.rename(columns = {'H': 'first_name','url_x': 'driver_url', 'url_y': 'race_url','number_y':'car_number','time_x':'time_completed','rank':'fastest_lap_rank','name':'grand_prix_name'}, inplace = True)
print(driver_combined.head(10))
# Out:
#    driverId   driverRef first_name     surname         dob nationality  \
# 0         1    hamilton      Lewis    Hamilton    7/1/1985     British
# 1         2    heidfeld       Nick    Heidfeld   10/5/1977      German
# 2         3     rosberg       Nico     Rosberg   27/6/1985      German
# 3         4      alonso   Fernando      Alonso   29/7/1981     Spanish
# 4         5  kovalainen     Heikki  Kovalainen  19/10/1981     Finnish
# 5         6    nakajima     Kazuki    Nakajima   11/1/1985    Japanese
# 6         9      kubica     Robert      Kubica   7/12/1984      Polish
# 7        14   coulthard      David   Coulthard   27/3/1971     British
# 8        17      webber       Mark      Webber   27/8/1976  Australian
# 9        18      button     Jenson      Button   19/1/1980     British
#
#                                        driver_url  resultId  raceId  \
# 0     http://en.wikipedia.org/wiki/Lewis_Hamilton         1      18
# ...

# %%
driver_combined.sort_values(by=['year'], inplace=True)

# %%
driver_combined.to_csv('F1 data/drivers_combined_data.csv')

# %%
laps_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/lapTimes.csv")
print(laps_df.head(10))
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342
# 5     841        20    6         1  1:32.605         92605
# 6     841        20    7         1  1:32.502         92502
# 7     841        20    8         1  1:32.537         92537
# 8     841        20    9         1  1:33.240         93240
# 9     841        20   10         1  1:32.572         92572

# %%
pitstops_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/pitStops.csv")
print(pitstops_df.head(10))
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842
# 5     841        22     1   13  17:24:29   23.643         23643
# 6     841        20     1   14  17:25:17   22.603         22603
# 7     841       814     1   14  17:26:03   24.863         24863
# 8     841       816     1   14  17:26:50   25.259         25259
# 9     841        67     1   15  17:27:34   25.342         25342

# %%
laps_combined = pd.merge(laps_df, pitstops_df, how='left', on=['raceId', 'driverId','lap'])
print(laps_combined.head(20))
# Out:
#     raceId  driverId  lap  position    time_x  milliseconds_x  stop    time_y  \
# 0      841        20    1         1  1:38.109           98109   NaN       NaN
# 1      841        20    2         1  1:33.006           93006   NaN       NaN
# 2      841        20    3         1  1:32.713           92713   NaN       NaN
# 3      841        20    4         1  1:32.803           92803   NaN       NaN
# 4      841        20    5         1  1:32.342           92342   NaN       NaN
# 5      841        20    6         1  1:32.605           92605   NaN       NaN
# 6      841        20    7         1  1:32.502           92502   NaN       NaN
# 7      841        20    8         1  1:32.537           92537   NaN       NaN
# 8      841        20    9         1  1:33.240           93240   NaN       NaN
# 9      841        20   10         1  1:32.572           92572   NaN       NaN
# 10     841        20   11         1  1:32.669           92669   NaN       NaN
# ...

# %%
laps_combined.rename(columns = {'time_x': 'lap_time', 'milliseconds_x':'milliseconds_lap','time_y': 'pit_time', 'duration':'pit_duration','milliseconds_y':'milliseconds_pit'}, inplace = True)
print(laps_combined.head(10))
# Out:
#    raceId  driverId  lap  position  lap_time  milliseconds_lap  stop pit_time  \
# 0     841        20    1         1  1:38.109             98109   NaN      NaN
# 1     841        20    2         1  1:33.006             93006   NaN      NaN
# 2     841        20    3         1  1:32.713             92713   NaN      NaN
# 3     841        20    4         1  1:32.803             92803   NaN      NaN
# 4     841        20    5         1  1:32.342             92342   NaN      NaN
# 5     841        20    6         1  1:32.605             92605   NaN      NaN
# 6     841        20    7         1  1:32.502             92502   NaN      NaN
# 7     841        20    8         1  1:32.537             92537   NaN      NaN
# 8     841        20    9         1  1:33.240             93240   NaN      NaN
# 9     841        20   10         1  1:32.572             92572   NaN      NaN
#
#   pit_duration  milliseconds_pit
# 0          NaN               NaN
# 1          NaN               NaN
# ...

# %%
races_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/races.csv")
print(races_df.head(10))
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
# 5       6  2009      6          6      Monaco Grand Prix  2009-05-24
# 6       7  2009      7          5     Turkish Grand Prix  2009-06-07
# 7       8  2009      8          9     British Grand Prix  2009-06-21
# 8       9  2009      9         20      German Grand Prix  2009-07-12
# 9      10  2009     10         11   Hungarian Grand Prix  2009-07-26
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# ...

# %%
races_df.drop(['time', 'url'], axis='columns', inplace=True)

# %%
laps_combined = pd.merge(races_df, laps_combined, on='raceId')
print(laps_combined.head(10))
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       1  2009      1          1  Australian Grand Prix  2009-03-29
# 2       1  2009      1          1  Australian Grand Prix  2009-03-29
# 3       1  2009      1          1  Australian Grand Prix  2009-03-29
# 4       1  2009      1          1  Australian Grand Prix  2009-03-29
# 5       1  2009      1          1  Australian Grand Prix  2009-03-29
# 6       1  2009      1          1  Australian Grand Prix  2009-03-29
# 7       1  2009      1          1  Australian Grand Prix  2009-03-29
# 8       1  2009      1          1  Australian Grand Prix  2009-03-29
# 9       1  2009      1          1  Australian Grand Prix  2009-03-29
#
#    driverId  lap  position  lap_time  milliseconds_lap  stop pit_time  \
# 0         1    1        13  1:49.088            109088   NaN      NaN
# ...

# %%
laps_combined = laps_combined.loc[laps_combined['year'] >= 2016]

# %%
laps_combined.sort_values(by=['date','lap','position'], inplace=True)
laps_combined.to_csv('F1 data/laps_combined_data.csv')

# %%
laps_combined_dup = laps_combined

# %%
laps_combined_compare = pd.merge(laps_combined, laps_combined_dup, on=['raceId','lap'])
print(laps_combined_compare.head(20))
# Out:
#     raceId  driverId_x  lap  position_x lap_time_x  milliseconds_lap_x  \
# 0      841          20    1           1   1:38.109               98109
# 1      841          20    1           1   1:38.109               98109
# 2      841          20    1           1   1:38.109               98109
# 3      841          20    1           1   1:38.109               98109
# 4      841          20    1           1   1:38.109               98109
# 5      841          20    1           1   1:38.109               98109
# 6      841          20    1           1   1:38.109               98109
# 7      841          20    1           1   1:38.109               98109
# 8      841          20    1           1   1:38.109               98109
# 9      841          20    1           1   1:38.109               98109
# 10     841          20    1           1   1:38.109               98109
# 11     841          20    1           1   1:38.109               98109
# ...

# %%
laps_combined_compare.rename(columns = {'driverId_x': 'driverId', 'lap_time_x':'lap_time','milliseconds_lap_x': 'milliseconds_lap',
                                        'stop_x':'stop','pit_time_x':'pit_time','pit_duration_x':'pit_duration','milliseconds_pit_x':'milliseconds_pit',
                                        'driverId_y':'driverId_compare','position_y':'position_compare','lap_time_y':'lap_time_compare',
                                        'milliseconds_lap_y':'milliseconds_lap_compare','stop_y':'stop_compare','pit_time_y':'pit_time_compare',
                                        'pit_duration_y':'pit_duration_compare','milliseconds_pit_y':'milliseconds_pit_compare'}, inplace = True)
print(laps_combined_compare.head(10))
# Out:
#    raceId  driverId  lap  position_x  lap_time  milliseconds_lap  stop  \
# 0     841        20    1           1  1:38.109             98109   NaN
# 1     841        20    1           1  1:38.109             98109   NaN
# 2     841        20    1           1  1:38.109             98109   NaN
# 3     841        20    1           1  1:38.109             98109   NaN
# 4     841        20    1           1  1:38.109             98109   NaN
# 5     841        20    1           1  1:38.109             98109   NaN
# 6     841        20    1           1  1:38.109             98109   NaN
# 7     841        20    1           1  1:38.109             98109   NaN
# 8     841        20    1           1  1:38.109             98109   NaN
# 9     841        20    1           1  1:38.109             98109   NaN
#
#   pit_time pit_duration  milliseconds_pit  driverId_compare  position_compare  \
# 0      NaN          NaN               NaN                20                 1
# ...

# %%
#laps_combined_compare.to_csv('F1 data/laps_combined_compare_data.csv')

# %%
races_df = pd.read_csv("C:/Users/Shearman Chua/Desktop/Com Sci Courses/Year 3 Semester 1/CZ4032-Data Analytics and Mining/Assignment/F1 data/races.csv")
print(races_df.head(10))
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
# 5       6  2009      6          6      Monaco Grand Prix  2009-05-24
# 6       7  2009      7          5     Turkish Grand Prix  2009-06-07
# 7       8  2009      8          9     British Grand Prix  2009-06-21
# 8       9  2009      9         20      German Grand Prix  2009-07-12
# 9      10  2009     10         11   Hungarian Grand Prix  2009-07-26
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# ...

# %%
races_df.drop(['time', 'url'], axis='columns', inplace=True)

# %%
laps_combined_compare = pd.merge(races_df, laps_combined_compare, on='raceId')
print(laps_combined_compare.head(10))
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       1  2009      1          1  Australian Grand Prix  2009-03-29
# 2       1  2009      1          1  Australian Grand Prix  2009-03-29
# 3       1  2009      1          1  Australian Grand Prix  2009-03-29
# 4       1  2009      1          1  Australian Grand Prix  2009-03-29
# 5       1  2009      1          1  Australian Grand Prix  2009-03-29
# 6       1  2009      1          1  Australian Grand Prix  2009-03-29
# 7       1  2009      1          1  Australian Grand Prix  2009-03-29
# 8       1  2009      1          1  Australian Grand Prix  2009-03-29
# 9       1  2009      1          1  Australian Grand Prix  2009-03-29
#
#    driverId  lap  position_x  lap_time  ...  pit_duration  milliseconds_pit  \
# 0         1    1          13  1:49.088  ...           NaN               NaN
# ...

# %%
print(laps_combined_compare.head(20))
# Out:
#     raceId  year  round  circuitId                   name        date  \
# 0        1  2009      1          1  Australian Grand Prix  2009-03-29
# 1        1  2009      1          1  Australian Grand Prix  2009-03-29
# 2        1  2009      1          1  Australian Grand Prix  2009-03-29
# 3        1  2009      1          1  Australian Grand Prix  2009-03-29
# 4        1  2009      1          1  Australian Grand Prix  2009-03-29
# 5        1  2009      1          1  Australian Grand Prix  2009-03-29
# 6        1  2009      1          1  Australian Grand Prix  2009-03-29
# 7        1  2009      1          1  Australian Grand Prix  2009-03-29
# 8        1  2009      1          1  Australian Grand Prix  2009-03-29
# 9        1  2009      1          1  Australian Grand Prix  2009-03-29
# 10       1  2009      1          1  Australian Grand Prix  2009-03-29
# 11       1  2009      1          1  Australian Grand Prix  2009-03-29
# ...

# %%
laps_combined_compare = laps_combined_compare.loc[laps_combined_compare['year'] >= 2016]

# %%
laps_combined_compare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 830640 entries, 6974095 to 7804734
# Data columns (total 23 columns):
# raceId                      830640 non-null int64
# year                        830640 non-null int64
# round                       830640 non-null int64
# circuitId                   830640 non-null int64
# name                        830640 non-null object
# date                        830640 non-null object
# driverId                    830640 non-null int64
# lap                         830640 non-null int64
# position_x                  830640 non-null int64
# lap_time                    830640 non-null object
# milliseconds_lap            830640 non-null int64
# stop                        31776 non-null float64
# pit_time                    31776 non-null object
# pit_duration                31776 non-null object
# milliseconds_pit            31776 non-null float64
# driverId_compare            830640 non-null int64
# ...

# %%
laps_combined_compare.sort_values(by=['date','lap','driverId'], inplace=True)
laps_combined_compare.to_csv('F1 data/laps_combined_compare_data.csv')

# %%
df = pd.read_csv("F1 data/constructors_combined_data.csv")

print(df.head())
# Out:
#    Unnamed: 0  constructorId constructorRef Constructor_name nationality  \
# 0       11028            105       maserati         Maserati     Italian
# 1       11029            128        gordini          Gordini      French
# 2       11030              6        ferrari          Ferrari     Italian
# 3       11031            105       maserati         Maserati     Italian
# 4       11027              6        ferrari          Ferrari     Italian
#
#                                  constructor_url  raceId  points  year  round  \
# 0          http://en.wikipedia.org/wiki/Maserati     790    15.0  1956      7
# 1           http://en.wikipedia.org/wiki/Gordini     790     0.0  1956      7
# 2  http://en.wikipedia.org/wiki/Scuderia_Ferrari     784    12.0  1956      1
# 3          http://en.wikipedia.org/wiki/Maserati     784    13.0  1956      1
# 4  http://en.wikipedia.org/wiki/Scuderia_Ferrari     790     9.0  1956      7
#
#    circuitId       grand_prix_name        date  \
# ...

# %%
import requests
import json

response = requests.get("http://ergast.com/api/f1/2020/results.json?limit=1000")
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
json_res = response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.4', 'series': 'f1', 'url': 'http://ergast.com/api/f1/2020/results.json', 'limit': '1000', 'offset': '0', 'total': '180', 'RaceTable': {'season': '2020', 'Races': [{'season': '2020', 'round': '1', 'url': 'https://en.wikipedia.org/wiki/2020_Austrian_Grand_Prix', 'raceName': 'Austrian Grand Prix', 'Circuit': {'circuitId': 'red_bull_ring', 'url': 'http://en.wikipedia.org/wiki/Red_Bull_Ring', 'circuitName': 'Red Bull Ring', 'Location': {'lat': '47.2197', 'long': '14.7647', 'locality': 'Spielburg', 'country': 'Austria'}}, 'date': '2020-07-05', 'time': '13:10:00Z', 'Results': [{'number': '77', 'position': '1', 'positionText': '1', 'points': '25', 'Driver': {'driverId': 'bottas', 'permanentNumber': '77', 'code': 'BOT', 'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas', 'givenName': 'Valtteri', 'familyName': 'Bottas', 'dateOfBirth': '1989-08-28', 'nationality': 'Finnish'}, 'Constructor': {'constructorId': 'mercedes', 'url': 'http://en.wikipedi
# ...

# %%
races = json_res['MRData']['RaceTable']
print(races)
# Out:
# {'season': '2020', 'Races': [{'season': '2020', 'round': '1', 'url': 'https://en.wikipedia.org/wiki/2020_Austrian_Grand_Prix', 'raceName': 'Austrian Grand Prix', 'Circuit': {'circuitId': 'red_bull_ring', 'url': 'http://en.wikipedia.org/wiki/Red_Bull_Ring', 'circuitName': 'Red Bull Ring', 'Location': {'lat': '47.2197', 'long': '14.7647', 'locality': 'Spielburg', 'country': 'Austria'}}, 'date': '2020-07-05', 'time': '13:10:00Z', 'Results': [{'number': '77', 'position': '1', 'positionText': '1', 'points': '25', 'Driver': {'driverId': 'bottas', 'permanentNumber': '77', 'code': 'BOT', 'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas', 'givenName': 'Valtteri', 'familyName': 'Bottas', 'dateOfBirth': '1989-08-28', 'nationality': 'Finnish'}, 'Constructor': {'constructorId': 'mercedes', 'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One', 'name': 'Mercedes', 'nationality': 'German'}, 'grid': '1', 'laps': '71', 'status': 'Finished', 'Time': {'millis': '5455739', 'time': '1:30
# ...

# %%
races_list = races['Races']
print(races_list)
# Out:
# [{'season': '2020', 'round': '1', 'url': 'https://en.wikipedia.org/wiki/2020_Austrian_Grand_Prix', 'raceName': 'Austrian Grand Prix', 'Circuit': {'circuitId': 'red_bull_ring', 'url': 'http://en.wikipedia.org/wiki/Red_Bull_Ring', 'circuitName': 'Red Bull Ring', 'Location': {'lat': '47.2197', 'long': '14.7647', 'locality': 'Spielburg', 'country': 'Austria'}}, 'date': '2020-07-05', 'time': '13:10:00Z', 'Results': [{'number': '77', 'position': '1', 'positionText': '1', 'points': '25', 'Driver': {'driverId': 'bottas', 'permanentNumber': '77', 'code': 'BOT', 'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas', 'givenName': 'Valtteri', 'familyName': 'Bottas', 'dateOfBirth': '1989-08-28', 'nationality': 'Finnish'}, 'Constructor': {'constructorId': 'mercedes', 'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One', 'name': 'Mercedes', 'nationality': 'German'}, 'grid': '1', 'laps': '71', 'status': 'Finished', 'Time': {'millis': '5455739', 'time': '1:30:55.739'}, 'FastestLap': {'r
# ...

# %%
season = ''
raceRound = ''
race_url = ''
race_name = ''
date = ''
for key, value in races_list[0].items():
    print("key: " + str(key))
    print("value: " + str(value))
    if(key == "season"):
        season = value
    elif(key == "round"):
        raceRound = value
    elif(key == "url"):
        race_url = value
    elif(key == "url"):
        race_url = value
    elif(key == "raceName"):
        race_name = value
    elif(key == "Circuit"):
        circuit_info = value
    elif(key == 'date'):
        date = value
    elif(key == "Results"):
        Results = value
# Out:
# key: season
# value: 2020
# key: round
# value: 1
# key: url
# value: https://en.wikipedia.org/wiki/2020_Austrian_Grand_Prix
# key: raceName
# value: Austrian Grand Prix
# key: Circuit
# value: {'circuitId': 'red_bull_ring', 'url': 'http://en.wikipedia.org/wiki/Red_Bull_Ring', 'circuitName': 'Red Bull Ring', 'Location': {'lat': '47.2197', 'long': '14.7647', 'locality': 'Spielburg', 'country': 'Austria'}}
# key: date
# value: 2020-07-05
# key: time
# value: 13:10:00Z
# key: Results
# ...

# %%
Results
# Out:
# [{'number': '77',
#   'position': '1',
#   'positionText': '1',
#   'points': '25',
#   'Driver': {'driverId': 'bottas',
#    'permanentNumber': '77',
#    'code': 'BOT',
#    'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas',
#    'givenName': 'Valtteri',
#    'familyName': 'Bottas',
#    'dateOfBirth': '1989-08-28',
#    'nationality': 'Finnish'},
#   'Constructor': {'constructorId': 'mercedes',
#    'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#    'name': 'Mercedes',
#    'nationality': 'German'},
#   'grid': '1',
#   'laps': '71',
#   'status': 'Finished',
#   'Time': {'millis': '5455739', 'time': '1:30:55.739'},
#   'FastestLap': {'rank': '2',
#    'lap': '68',
#    'Time': {'time': '1:07.657'},
#    'AverageSpeed': {'units': 'kph', 'speed': '229.758'}}},
#  {'number': '16',
#   'position': '2',
#   'positionText': '2',
#   'points': '18',
#   'Driver': {'driverId': 'leclerc',
#    'permanentNumber': '16',
#    'code': 'LEC',
# ...
